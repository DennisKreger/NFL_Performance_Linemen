# %%
import csv
import os
import pandas as pd
import numpy as np

# %%
players_data_to_load = "players.csv"
week2_data_to_load = "week2.csv"
plays_data_to_load = "plays.csv"
pff_data_to_load = "pffScoutingData.csv"
games_data_to_load = "games.csv"

# %%
players_df = pd.read_csv(players_data_to_load)
players_df
# Out:
#       nflId height  weight   birthDate collegeName officialPosition  \
# 0     25511    6-4     225  1977-08-03    Michigan               QB
# 1     28963    6-5     240  1982-03-02   Miami, O.               QB
# 2     29550    6-4     328  1982-01-22    Arkansas                T
# 3     29851    6-2     225  1983-12-02  California               QB
# 4     30078    6-2     228  1982-11-24     Harvard               QB
# ...     ...    ...     ...         ...         ...              ...
# 1674  53991    6-1     320         NaN         NaN               DT
# 1675  53994    6-5     300         NaN         NaN                C
# 1676  53999    6-4     312         NaN         NaN               DT
# 1677  54006    6-6     330         NaN         NaN                T
# 1678  54038    6-6     245         NaN         NaN               QB
#
#              displayName
# 0              Tom Brady
# 1     Ben Roethlisberger
# 2           Jason Peters
# 3          Aaron Rodgers
# ...

# %%
week2_df = pd.read_csv(week2_data_to_load)
week2_df
# Out:
#              gameId  playId    nflId  frameId                     time  \
# 0        2021091600      65  40031.0        1  2021-09-17T00:23:09.600
# 1        2021091600      65  40031.0        2  2021-09-17T00:23:09.700
# 2        2021091600      65  40031.0        3  2021-09-17T00:23:09.800
# 3        2021091600      65  40031.0        4  2021-09-17T00:23:09.900
# 4        2021091600      65  40031.0        5  2021-09-17T00:23:10.000
# ...             ...     ...      ...      ...                      ...
# 1042769  2021092000    3759      NaN       52  2021-09-21T03:07:54.900
# 1042770  2021092000    3759      NaN       53  2021-09-21T03:07:55.000
# 1042771  2021092000    3759      NaN       54  2021-09-21T03:07:55.100
# 1042772  2021092000    3759      NaN       55  2021-09-21T03:07:55.200
# 1042773  2021092000    3759      NaN       56  2021-09-21T03:07:55.300
#
#          jerseyNumber      team playDirection      x      y      s     a  \
# ...

# %%
week2_players = players_df.merge(week2_df, how='left')
week2_players
# Out:
#         nflId height  weight   birthDate collegeName officialPosition  \
# 0       25511    6-4     225  1977-08-03    Michigan               QB
# 1       25511    6-4     225  1977-08-03    Michigan               QB
# 2       25511    6-4     225  1977-08-03    Michigan               QB
# 3       25511    6-4     225  1977-08-03    Michigan               QB
# 4       25511    6-4     225  1977-08-03    Michigan               QB
# ...       ...    ...     ...         ...         ...              ...
# 997954  53991    6-1     320         NaN         NaN               DT
# 997955  53994    6-5     300         NaN         NaN                C
# 997956  53999    6-4     312         NaN         NaN               DT
# 997957  54006    6-6     330         NaN         NaN                T
# 997958  54038    6-6     245         NaN         NaN               QB
#
#             displayName        gameId  playId  frameId  ... team  \
# ...

# %% [markdown]
# ## Centers

# %%
week2_players_C = week2_players[week2_players['officialPosition'] == 'C']
week2_players_C
# Out:
#         nflId height  weight   birthDate collegeName officialPosition  \
# 14011   34472    6-4     311  1985-11-19  California                C
# 14012   34472    6-4     311  1985-11-19  California                C
# 14013   34472    6-4     311  1985-11-19  California                C
# 14014   34472    6-4     311  1985-11-19  California                C
# 14015   34472    6-4     311  1985-11-19  California                C
# ...       ...    ...     ...         ...         ...              ...
# 974730  53516    6-3     310         NaN         NaN                C
# 974731  53516    6-3     310         NaN         NaN                C
# 979897  53543    6-3     300         NaN         NaN                C
# 989923  53619    6-3     330         NaN         NaN                C
# 997955  53994    6-5     300         NaN         NaN                C
#
#            displayName        gameId  playId  frameId  ... team  \
# ...

# %%
week2_players_C = week2_players_C[week2_players_C['event'] != 'None']
week2_players_C
# Out:
#         nflId height  weight   birthDate collegeName officialPosition  \
# 14016   34472    6-4     311  1985-11-19  California                C
# 14017   34472    6-4     311  1985-11-19  California                C
# 14040   34472    6-4     311  1985-11-19  California                C
# 14041   34472    6-4     311  1985-11-19  California                C
# 14051   34472    6-4     311  1985-11-19  California                C
# ...       ...    ...     ...         ...         ...              ...
# 974726  53516    6-3     310         NaN         NaN                C
# 974727  53516    6-3     310         NaN         NaN                C
# 979897  53543    6-3     300         NaN         NaN                C
# 989923  53619    6-3     330         NaN         NaN                C
# 997955  53994    6-5     300         NaN         NaN                C
#
#            displayName        gameId  playId  frameId  ... team  \
# ...

# %%
week2_players_C = week2_players_C.sort_values('a', ascending = False)
week2_players_C
# Out:
#         nflId height  weight   birthDate           collegeName  \
# 82492   38629    6-3     308  1989-07-02               Georgia
# 671978  47801    6-3     305  1995-06-20  North Carolina State
# 14235   34472    6-4     311  1985-11-19            California
# 634854  46284    6-5     317  1994-11-24               Alabama
# 14236   34472    6-4     311  1985-11-19            California
# ...       ...    ...     ...         ...                   ...
# 772722  48512    6-4     300  1997-02-14            Penn State
# 872680  52564    6-3     310  1998-07-25       San Diego State
# 979897  53543    6-3     300         NaN                   NaN
# 989923  53619    6-3     330         NaN                   NaN
# 997955  53994    6-5     300         NaN                   NaN
#
#        officialPosition       displayName        gameId  playId  frameId  ...  \
# 82492                 C         Ben Jones  2.021092e+09  3516.0     37.0  ...
# ...

# %%
week2_players_C = week2_players_C.dropna()

# %%
cleaned_C= week2_players_C[['nflId', 'height', 'weight', 'displayName', 'gameId', 'playId', 'frameId', 'team', 's', 'a', 'dis', 'event']]
cleaned_C
# Out:
#         nflId height  weight        displayName        gameId  playId  \
# 82492   38629    6-3     308          Ben Jones  2.021092e+09  3516.0
# 671978  47801    6-3     305   Garrett Bradbury  2.021092e+09  3433.0
# 14235   34472    6-4     311          Alex Mack  2.021092e+09  1134.0
# 634854  46284    6-5     317    Bradley Bozeman  2.021092e+09  3676.0
# 14236   34472    6-4     311          Alex Mack  2.021092e+09  1134.0
# ...       ...    ...     ...                ...           ...     ...
# 545698  46089    6-5     311       Frank Ragnow  2.021092e+09  2959.0
# 545699  46089    6-5     311       Frank Ragnow  2.021092e+09  2959.0
# 187372  41390    6-3     301      Corey Linsley  2.021092e+09  3066.0
# 849861  52491    6-4     315  Lloyd Cushenberry  2.021092e+09  2120.0
# 122103  40070    6-4     307       J.C. Tretter  2.021092e+09   164.0
#
#         frameId team     s     a   dis                      event
# ...

# %% [markdown]
# ## Guards

# %%
week2_players_G = week2_players[week2_players['officialPosition'] == 'G']
week2_players_G
# Out:
#         nflId height  weight   birthDate collegeName officialPosition  \
# 26414   35472    6-5     325  1988-06-06     Indiana                G
# 26415   35472    6-5     325  1988-06-06     Indiana                G
# 26416   35472    6-5     325  1988-06-06     Indiana                G
# 26417   35472    6-5     325  1988-06-06     Indiana                G
# 26418   35472    6-5     325  1988-06-06     Indiana                G
# ...       ...    ...     ...         ...         ...              ...
# 996782  53861    6-5     330         NaN         NaN                G
# 996783  53861    6-5     330         NaN         NaN                G
# 996784  53861    6-5     330         NaN         NaN                G
# 996785  53861    6-5     330         NaN         NaN                G
# 997107  53954    6-5     319         NaN         NaN                G
#
#            displayName        gameId  playId  frameId  ... team  \
# ...

# %%
week2_players_G = week2_players_G[week2_players_G['event'] != 'None']
week2_players_G
# Out:
#         nflId height  weight   birthDate collegeName officialPosition  \
# 26419   35472    6-5     325  1988-06-06     Indiana                G
# 26420   35472    6-5     325  1988-06-06     Indiana                G
# 26442   35472    6-5     325  1988-06-06     Indiana                G
# 26444   35472    6-5     325  1988-06-06     Indiana                G
# 26453   35472    6-5     325  1988-06-06     Indiana                G
# ...       ...    ...     ...         ...         ...              ...
# 996720  53861    6-5     330         NaN         NaN                G
# 996725  53861    6-5     330         NaN         NaN                G
# 996731  53861    6-5     330         NaN         NaN                G
# 996780  53861    6-5     330         NaN         NaN                G
# 997107  53954    6-5     319         NaN         NaN                G
#
#            displayName        gameId  playId  frameId  ... team  \
# ...

# %%
week2_players_G = week2_players_G.sort_values('a', ascending = False)

# %%
week2_players_G = week2_players_G.dropna()

# %%
cleaned_G = week2_players_G[['nflId', 'height', 'weight', 'displayName', 'gameId', 'playId', 'frameId', 'team', 's', 'a', 'dis', 'event']]
cleaned_G
# Out:
#         nflId height  weight         displayName        gameId  playId  \
# 845287  52483    6-4     305       Jonah Jackson  2.021092e+09  3546.0
# 845286  52483    6-4     305       Jonah Jackson  2.021092e+09  3546.0
# 130620  40124    6-5     310  David Quessenberry  2.021092e+09  1746.0
# 130619  40124    6-5     310  David Quessenberry  2.021092e+09  1746.0
# 154165  41242    6-4     315         Zack Martin  2.021092e+09   322.0
# ...       ...    ...     ...                 ...           ...     ...
# 216401  42352    6-6     329       Ereck Flowers  2.021092e+09   111.0
# 298960  43045    6-4     330       Quinton Spain  2.021092e+09  1987.0
# 298929  43045    6-4     330       Quinton Spain  2.021092e+09  1609.0
# 298928  43045    6-4     330       Quinton Spain  2.021092e+09  1609.0
# 202149  41939    6-6     325      Andrew Norwell  2.021092e+09  1058.0
#
#         frameId team     s     a   dis                  event
# ...

# %% [markdown]
# ## Tackles

# %%
week2_players_T = week2_players[week2_players['officialPosition'] == 'T']
week2_players_T
# Out:
#         nflId height  weight   birthDate collegeName officialPosition  \
# 2664    29550    6-4     328  1982-01-22    Arkansas                T
# 2665    29550    6-4     328  1982-01-22    Arkansas                T
# 2666    29550    6-4     328  1982-01-22    Arkansas                T
# 2667    29550    6-4     328  1982-01-22    Arkansas                T
# 2668    29550    6-4     328  1982-01-22    Arkansas                T
# ...       ...    ...     ...         ...         ...              ...
# 986368  53584    6-5     315         NaN         NaN                T
# 986986  53590    6-8     315         NaN         NaN                T
# 992445  53635    6-7     305         NaN         NaN                T
# 996786  53868    6-6     315         NaN         NaN                T
# 997957  54006    6-6     330         NaN         NaN                T
#
#            displayName        gameId  playId  frameId  ... team  \
# ...

# %%
week2_players_T = week2_players_T[week2_players_T['event'] != 'None']
week2_players_T
# Out:
#         nflId height  weight   birthDate collegeName officialPosition  \
# 2669    29550    6-4     328  1982-01-22    Arkansas                T
# 2670    29550    6-4     328  1982-01-22    Arkansas                T
# 2682    29550    6-4     328  1982-01-22    Arkansas                T
# 2728    29550    6-4     328  1982-01-22    Arkansas                T
# 2729    29550    6-4     328  1982-01-22    Arkansas                T
# ...       ...    ...     ...         ...         ...              ...
# 986368  53584    6-5     315         NaN         NaN                T
# 986986  53590    6-8     315         NaN         NaN                T
# 992445  53635    6-7     305         NaN         NaN                T
# 996786  53868    6-6     315         NaN         NaN                T
# 997957  54006    6-6     330         NaN         NaN                T
#
#            displayName        gameId  playId  frameId  ... team  \
# ...

# %%
week2_players_T = week2_players_T.sort_values('a', ascending = False)

# %%
week2_players_T = week2_players_T.dropna()

# %%
cleaned_T = week2_players_T[['nflId', 'height', 'weight', 'displayName', 'gameId', 'playId', 'frameId', 'team', 's', 'a', 'dis', 'event']]
cleaned_T
# Out:
#         nflId height  weight     displayName        gameId  playId  frameId  \
# 234578  42377    6-6     338   Donovan Smith  2.021092e+09  1840.0     15.0
# 454852  44876    6-5     325    Taylor Moton  2.021092e+09  3355.0     32.0
# 454853  44876    6-5     325    Taylor Moton  2.021092e+09  3355.0     33.0
# 19621   35443    6-5     320  Trent Williams  2.021092e+09  1215.0     34.0
# 19620   35443    6-5     320  Trent Williams  2.021092e+09  1215.0     33.0
# ...       ...    ...     ...             ...           ...     ...      ...
# 234569  42377    6-6     338   Donovan Smith  2.021092e+09  1840.0      6.0
# 234460  42377    6-6     338   Donovan Smith  2.021092e+09  1408.0      3.0
# 792711  52421    6-5     322   Tristan Wirfs  2.021092e+09  3365.0      6.0
# 234398  42377    6-6     338   Donovan Smith  2.021092e+09  1362.0      6.0
# 438444  44846    6-6     320    Cam Robinson  2.021092e+09  1058.0      7.0
#
#        team     s     a   dis                  event
# ...

# %% [markdown]
# ## Plays, PFF, & Games data added

# %%
plays_df = pd.read_csv(plays_data_to_load)
plays_df
# Out:
#           gameId  playId                                    playDescription  \
# 0     2021090900      97  (13:33) (Shotgun) T.Brady pass incomplete deep...
# 1     2021090900     137  (13:18) (Shotgun) D.Prescott pass deep left to...
# 2     2021090900     187  (12:23) (Shotgun) D.Prescott pass short middle...
# 3     2021090900     282  (9:56) D.Prescott pass incomplete deep left to...
# 4     2021090900     349  (9:46) (Shotgun) D.Prescott pass incomplete sh...
# ...          ...     ...                                                ...
# 8552  2021110100    4310  (1:56) (Shotgun) P.Mahomes sacked at NYG 16 fo...
# 8553  2021110100    4363  (1:07) (Shotgun) D.Jones pass short right to E...
# 8554  2021110100    4392  (1:01) (No Huddle, Shotgun) D.Jones sacked at ...
# 8555  2021110100    4411  (:39) (No Huddle, Shotgun) D.Jones pass incomp...
# 8556  2021110100    4433  (:35) (Shotgun) D.Jones sacked at NYG 14 for -...
#
# ...

# %%
pff_df = pd.read_csv(pff_data_to_load)
pff_df
# Out:
#             gameId  playId  nflId    pff_role pff_positionLinedUp  pff_hit  \
# 0       2021090900      97  25511        Pass                  QB      NaN
# 1       2021090900      97  35481  Pass Route                TE-L      NaN
# 2       2021090900      97  35634  Pass Route                 LWR      NaN
# 3       2021090900      97  39985  Pass Route                HB-R      NaN
# 4       2021090900      97  40151  Pass Block                   C      NaN
# ...            ...     ...    ...         ...                 ...      ...
# 188249  2021110100    4433  52507  Pass Block                  LT      NaN
# 188250  2021110100    4433  52546    Coverage               SCBoR      0.0
# 188251  2021110100    4433  52573  Pass Route               SLoWR      NaN
# 188252  2021110100    4433  52585   Pass Rush                 LEO      0.0
# 188253  2021110100    4433  53449  Pass Route                 LWR      NaN
#
#         pff_hurry  pff_sack  pff_beatenByDefender  pff_hitAllowed  \
# ...

# %%
games_df = pd.read_csv(games_data_to_load)
games_df
# Out:
#          gameId  season  week    gameDate gameTimeEastern homeTeamAbbr  \
# 0    2021090900    2021     1  09/09/2021        20:20:00           TB
# 1    2021091200    2021     1  09/12/2021        13:00:00          ATL
# 2    2021091201    2021     1  09/12/2021        13:00:00          BUF
# 3    2021091202    2021     1  09/12/2021        13:00:00          CAR
# 4    2021091203    2021     1  09/12/2021        13:00:00          CIN
# ..          ...     ...   ...         ...             ...          ...
# 117  2021103109    2021     8  10/31/2021        16:05:00          SEA
# 118  2021103110    2021     8  10/31/2021        16:25:00          DEN
# 119  2021103111    2021     8  10/31/2021        16:25:00           NO
# 120  2021103112    2021     8  10/31/2021        20:20:00          MIN
# 121  2021110100    2021     8  11/01/2021        20:15:00           KC
#
#     visitorTeamAbbr
# 0               DAL
# 1               PHI
# 2               PIT
# 3               NYJ
# ...

# %% [markdown]
# # Merging all data & Cleaning

# %% [markdown]
# ## Center

# %%
w2_C = cleaned_C.merge(plays_df, how="left")
w2_C.head()
# Out:
#    nflId height  weight       displayName        gameId  playId  frameId team  \
# 0  38629    6-3     308         Ben Jones  2.021092e+09  3516.0     37.0  TEN
# 1  47801    6-3     305  Garrett Bradbury  2.021092e+09  3433.0     32.0  MIN
# 2  34472    6-4     311         Alex Mack  2.021092e+09  1134.0     32.0   SF
# 3  46284    6-5     317   Bradley Bozeman  2.021092e+09  3676.0     47.0  BAL
# 4  34472    6-4     311         Alex Mack  2.021092e+09  1134.0     33.0   SF
#
#       s     a  ...  foulNFLId3 absoluteYardlineNumber offenseFormation  \
# 0  0.59  5.02  ...         NaN                   55.0            EMPTY
# 1  2.29  4.32  ...         NaN                  101.0          SHOTGUN
# 2  1.23  3.77  ...         NaN                   47.0       SINGLEBACK
# 3  4.76  3.75  ...         NaN                   12.0          SHOTGUN
# 4  0.72  3.67  ...         NaN                   47.0       SINGLEBACK
#
#          personnelO  defendersInBox        personnelD dropBackType  \
# ...

# %%
w2_C.drop(columns=[['possessionTeam','pff_passCoverage','pff_passCoverageType']], inplace=True, errors='ignore')

# %%
w2_C = w2_C.merge(pff_df, how='left')
w2_C.head()
# Out:
#    nflId height  weight       displayName        gameId  playId  frameId team  \
# 0  38629    6-3     308         Ben Jones  2.021092e+09  3516.0     37.0  TEN
# 1  47801    6-3     305  Garrett Bradbury  2.021092e+09  3433.0     32.0  MIN
# 2  34472    6-4     311         Alex Mack  2.021092e+09  1134.0     32.0   SF
# 3  46284    6-5     317   Bradley Bozeman  2.021092e+09  3676.0     47.0  BAL
# 4  34472    6-4     311         Alex Mack  2.021092e+09  1134.0     33.0   SF
#
#       s     a  ...  pff_hit pff_hurry pff_sack  pff_beatenByDefender  \
# 0  0.59  5.02  ...      NaN       NaN      NaN                   0.0
# 1  2.29  4.32  ...      NaN       NaN      NaN                   0.0
# 2  1.23  3.77  ...      NaN       NaN      NaN                   0.0
# 3  4.76  3.75  ...      NaN       NaN      NaN                   0.0
# 4  0.72  3.67  ...      NaN       NaN      NaN                   0.0
#
#    pff_hitAllowed  pff_hurryAllowed pff_sackAllowed pff_nflIdBlockedPlayer  \
# ...

# %%
w2_C = w2_C.merge(games_df, how='left')
w2_C.head()
# Out:
#    nflId height  weight       displayName        gameId  playId  frameId team  \
# 0  38629    6-3     308         Ben Jones  2.021092e+09  3516.0     37.0  TEN
# 1  47801    6-3     305  Garrett Bradbury  2.021092e+09  3433.0     32.0  MIN
# 2  34472    6-4     311         Alex Mack  2.021092e+09  1134.0     32.0   SF
# 3  46284    6-5     317   Bradley Bozeman  2.021092e+09  3676.0     47.0  BAL
# 4  34472    6-4     311         Alex Mack  2.021092e+09  1134.0     33.0   SF
#
#       s     a  ...  pff_sackAllowed pff_nflIdBlockedPlayer pff_blockType  \
# 0  0.59  5.02  ...              0.0                41786.0            PP
# 1  2.29  4.32  ...              0.0                35522.0            SW
# 2  1.23  3.77  ...              0.0                43378.0            PA
# 3  4.76  3.75  ...              0.0                41348.0            PR
# 4  0.72  3.67  ...              0.0                43378.0            PA
#
# ...

# %%
w2_C.drop(columns=['homeTeamAbbr', 'visitorTeamAbbr','gameDate', 'gameTimeEastern', 'season'], inplace=True, errors='ignore')
w2_C
# Out:
#       nflId height  weight        displayName        gameId  playId  frameId  \
# 0     38629    6-3     308          Ben Jones  2.021092e+09  3516.0     37.0
# 1     47801    6-3     305   Garrett Bradbury  2.021092e+09  3433.0     32.0
# 2     34472    6-4     311          Alex Mack  2.021092e+09  1134.0     32.0
# 3     46284    6-5     317    Bradley Bozeman  2.021092e+09  3676.0     47.0
# 4     34472    6-4     311          Alex Mack  2.021092e+09  1134.0     33.0
# ...     ...    ...     ...                ...           ...     ...      ...
# 3078  46089    6-5     311       Frank Ragnow  2.021092e+09  2959.0      6.0
# 3079  46089    6-5     311       Frank Ragnow  2.021092e+09  2959.0      7.0
# 3080  41390    6-3     301      Corey Linsley  2.021092e+09  3066.0      6.0
# 3081  52491    6-4     315  Lloyd Cushenberry  2.021092e+09  2120.0      7.0
# 3082  40070    6-4     307       J.C. Tretter  2.021092e+09   164.0      6.0
#
# ...

# %%
w2_C.to_csv('Resources/center_w2.csv', sep=',', index=False)

# %%
w2_C_df = pd.read_csv('Resources/center_w2.csv')
w2_C_df.head()
# Out:
#    nflId height  weight       displayName        gameId  playId  frameId team  \
# 0  38629    6-3     308         Ben Jones  2.021092e+09  3516.0     37.0  TEN
# 1  47801    6-3     305  Garrett Bradbury  2.021092e+09  3433.0     32.0  MIN
# 2  34472    6-4     311         Alex Mack  2.021092e+09  1134.0     32.0   SF
# 3  46284    6-5     317   Bradley Bozeman  2.021092e+09  3676.0     47.0  BAL
# 4  34472    6-4     311         Alex Mack  2.021092e+09  1134.0     33.0   SF
#
#       s     a  ...  pff_hurry pff_sack pff_beatenByDefender  pff_hitAllowed  \
# 0  0.59  5.02  ...        NaN      NaN                  0.0             0.0
# 1  2.29  4.32  ...        NaN      NaN                  0.0             0.0
# 2  1.23  3.77  ...        NaN      NaN                  0.0             0.0
# 3  4.76  3.75  ...        NaN      NaN                  0.0             0.0
# 4  0.72  3.67  ...        NaN      NaN                  0.0             0.0
#
# ...

# %% [markdown]
# ## Guard

# %%
w2_G = cleaned_G.merge(plays_df, how="left")
w2_G.head()
# Out:
#    nflId height  weight         displayName        gameId  playId  frameId  \
# 0  52483    6-4     305       Jonah Jackson  2.021092e+09  3546.0     36.0
# 1  52483    6-4     305       Jonah Jackson  2.021092e+09  3546.0     35.0
# 2  40124    6-5     310  David Quessenberry  2.021092e+09  1746.0     35.0
# 3  40124    6-5     310  David Quessenberry  2.021092e+09  1746.0     34.0
# 4  41242    6-4     315         Zack Martin  2.021092e+09   322.0     36.0
#
#   team     s     a  ...  foulNFLId3 absoluteYardlineNumber offenseFormation  \
# 0  DET  0.78  4.67  ...         NaN                   19.0          SHOTGUN
# 1  DET  1.34  4.50  ...         NaN                   19.0          SHOTGUN
# 2  TEN  0.70  4.45  ...         NaN                  104.0          SHOTGUN
# 3  TEN  1.25  4.44  ...         NaN                  104.0          SHOTGUN
# 4  DAL  0.78  4.33  ...         NaN                   46.0          SHOTGUN
#
# ...

# %%
w2_G.drop(columns=[['possessionTeam','pff_passCoverage','pff_passCoverageType']], inplace=True, errors='ignore')
w2_G.head()
# Out:
#    nflId height  weight         displayName        gameId  playId  frameId  \
# 0  52483    6-4     305       Jonah Jackson  2.021092e+09  3546.0     36.0
# 1  52483    6-4     305       Jonah Jackson  2.021092e+09  3546.0     35.0
# 2  40124    6-5     310  David Quessenberry  2.021092e+09  1746.0     35.0
# 3  40124    6-5     310  David Quessenberry  2.021092e+09  1746.0     34.0
# 4  41242    6-4     315         Zack Martin  2.021092e+09   322.0     36.0
#
#   team     s     a  ...  foulNFLId3 absoluteYardlineNumber offenseFormation  \
# 0  DET  0.78  4.67  ...         NaN                   19.0          SHOTGUN
# 1  DET  1.34  4.50  ...         NaN                   19.0          SHOTGUN
# 2  TEN  0.70  4.45  ...         NaN                  104.0          SHOTGUN
# 3  TEN  1.25  4.44  ...         NaN                  104.0          SHOTGUN
# 4  DAL  0.78  4.33  ...         NaN                   46.0          SHOTGUN
#
# ...

# %%
w2_G = w2_G.merge(pff_df, how='left')
w2_G.head()
# Out:
#    nflId height  weight         displayName        gameId  playId  frameId  \
# 0  52483    6-4     305       Jonah Jackson  2.021092e+09  3546.0     36.0
# 1  52483    6-4     305       Jonah Jackson  2.021092e+09  3546.0     35.0
# 2  40124    6-5     310  David Quessenberry  2.021092e+09  1746.0     35.0
# 3  40124    6-5     310  David Quessenberry  2.021092e+09  1746.0     34.0
# 4  41242    6-4     315         Zack Martin  2.021092e+09   322.0     36.0
#
#   team     s     a  ...  pff_hit pff_hurry pff_sack  pff_beatenByDefender  \
# 0  DET  0.78  4.67  ...      NaN       NaN      NaN                   0.0
# 1  DET  1.34  4.50  ...      NaN       NaN      NaN                   0.0
# 2  TEN  0.70  4.45  ...      NaN       NaN      NaN                   0.0
# 3  TEN  1.25  4.44  ...      NaN       NaN      NaN                   0.0
# 4  DAL  0.78  4.33  ...      NaN       NaN      NaN                   0.0
#
# ...

# %%
w2_G = w2_G.merge(games_df, how='left')
w2_G.head()
# Out:
#    nflId height  weight         displayName        gameId  playId  frameId  \
# 0  52483    6-4     305       Jonah Jackson  2.021092e+09  3546.0     36.0
# 1  52483    6-4     305       Jonah Jackson  2.021092e+09  3546.0     35.0
# 2  40124    6-5     310  David Quessenberry  2.021092e+09  1746.0     35.0
# 3  40124    6-5     310  David Quessenberry  2.021092e+09  1746.0     34.0
# 4  41242    6-4     315         Zack Martin  2.021092e+09   322.0     36.0
#
#   team     s     a  ...  pff_sackAllowed pff_nflIdBlockedPlayer pff_blockType  \
# 0  DET  0.78  4.67  ...              0.0                43426.0            PP
# 1  DET  1.34  4.50  ...              0.0                43426.0            PP
# 2  TEN  0.70  4.45  ...              0.0                52456.0            PP
# 3  TEN  1.25  4.44  ...              0.0                52456.0            PP
# 4  DAL  0.78  4.33  ...              0.0                42559.0            PT
#
# ...

# %%
w2_G.drop(columns=['homeTeamAbbr', 'visitorTeamAbbr','gameDate', 'gameTimeEastern', 'season'], inplace=True, errors='ignore')
w2_G.head()
# Out:
#    nflId height  weight         displayName        gameId  playId  frameId  \
# 0  52483    6-4     305       Jonah Jackson  2.021092e+09  3546.0     36.0
# 1  52483    6-4     305       Jonah Jackson  2.021092e+09  3546.0     35.0
# 2  40124    6-5     310  David Quessenberry  2.021092e+09  1746.0     35.0
# 3  40124    6-5     310  David Quessenberry  2.021092e+09  1746.0     34.0
# 4  41242    6-4     315         Zack Martin  2.021092e+09   322.0     36.0
#
#   team     s     a  ...  pff_hurry pff_sack pff_beatenByDefender  \
# 0  DET  0.78  4.67  ...        NaN      NaN                  0.0
# 1  DET  1.34  4.50  ...        NaN      NaN                  0.0
# 2  TEN  0.70  4.45  ...        NaN      NaN                  0.0
# 3  TEN  1.25  4.44  ...        NaN      NaN                  0.0
# 4  DAL  0.78  4.33  ...        NaN      NaN                  0.0
#
#    pff_hitAllowed  pff_hurryAllowed  pff_sackAllowed pff_nflIdBlockedPlayer  \
# ...

# %%
w2_G.to_csv('Resources/guard_w2.csv', sep=',', index=False)

# %%
w2_G_df = pd.read_csv('Resources/guard_w2.csv')
w2_G_df.head()
# Out:
#    nflId height  weight         displayName        gameId  playId  frameId  \
# 0  52483    6-4     305       Jonah Jackson  2.021092e+09  3546.0     36.0
# 1  52483    6-4     305       Jonah Jackson  2.021092e+09  3546.0     35.0
# 2  40124    6-5     310  David Quessenberry  2.021092e+09  1746.0     35.0
# 3  40124    6-5     310  David Quessenberry  2.021092e+09  1746.0     34.0
# 4  41242    6-4     315         Zack Martin  2.021092e+09   322.0     36.0
#
#   team     s     a  ...  pff_hurry pff_sack pff_beatenByDefender  \
# 0  DET  0.78  4.67  ...        NaN      NaN                  0.0
# 1  DET  1.34  4.50  ...        NaN      NaN                  0.0
# 2  TEN  0.70  4.45  ...        NaN      NaN                  0.0
# 3  TEN  1.25  4.44  ...        NaN      NaN                  0.0
# 4  DAL  0.78  4.33  ...        NaN      NaN                  0.0
#
#    pff_hitAllowed  pff_hurryAllowed  pff_sackAllowed pff_nflIdBlockedPlayer  \
# ...

# %% [markdown]
# ## Tackle

# %%
w2_T = cleaned_T.merge(plays_df, how="left")
w2_T.head()
# Out:
#    nflId height  weight     displayName        gameId  playId  frameId team  \
# 0  42377    6-6     338   Donovan Smith  2.021092e+09  1840.0     15.0   TB
# 1  44876    6-5     325    Taylor Moton  2.021092e+09  3355.0     32.0  CAR
# 2  44876    6-5     325    Taylor Moton  2.021092e+09  3355.0     33.0  CAR
# 3  35443    6-5     320  Trent Williams  2.021092e+09  1215.0     34.0   SF
# 4  35443    6-5     320  Trent Williams  2.021092e+09  1215.0     33.0   SF
#
#       s     a  ...  foulNFLId3 absoluteYardlineNumber offenseFormation  \
# 0  1.68  4.75  ...         NaN                   46.0       SINGLEBACK
# 1  1.40  4.64  ...         NaN                   48.0       SINGLEBACK
# 2  1.09  4.55  ...         NaN                   48.0       SINGLEBACK
# 3  2.44  4.55  ...         NaN                   40.0           I_FORM
# 4  2.82  4.52  ...         NaN                   40.0           I_FORM
#
#          personnelO  defendersInBox        personnelD dropBackType  \
# ...

# %%
w2_T.drop(columns=['possessionTeam','pff_passCoverage','pff_passCoverageType'], inplace=True, errors='ignore')
w2_T.head()
# Out:
#    nflId height  weight     displayName        gameId  playId  frameId team  \
# 0  42377    6-6     338   Donovan Smith  2.021092e+09  1840.0     15.0   TB
# 1  44876    6-5     325    Taylor Moton  2.021092e+09  3355.0     32.0  CAR
# 2  44876    6-5     325    Taylor Moton  2.021092e+09  3355.0     33.0  CAR
# 3  35443    6-5     320  Trent Williams  2.021092e+09  1215.0     34.0   SF
# 4  35443    6-5     320  Trent Williams  2.021092e+09  1215.0     33.0   SF
#
#       s     a  ...  foulNFLId2 foulName3 foulNFLId3  absoluteYardlineNumber  \
# 0  1.68  4.75  ...         NaN       NaN        NaN                    46.0
# 1  1.40  4.64  ...         NaN       NaN        NaN                    48.0
# 2  1.09  4.55  ...         NaN       NaN        NaN                    48.0
# 3  2.44  4.55  ...         NaN       NaN        NaN                    40.0
# 4  2.82  4.52  ...         NaN       NaN        NaN                    40.0
#
# ...

# %%
w2_T = w2_T.merge(pff_df, how='left')
w2_T.head()
# Out:
#    nflId height  weight     displayName        gameId  playId  frameId team  \
# 0  42377    6-6     338   Donovan Smith  2.021092e+09  1840.0     15.0   TB
# 1  44876    6-5     325    Taylor Moton  2.021092e+09  3355.0     32.0  CAR
# 2  44876    6-5     325    Taylor Moton  2.021092e+09  3355.0     33.0  CAR
# 3  35443    6-5     320  Trent Williams  2.021092e+09  1215.0     34.0   SF
# 4  35443    6-5     320  Trent Williams  2.021092e+09  1215.0     33.0   SF
#
#       s     a  ...  pff_hit pff_hurry pff_sack  pff_beatenByDefender  \
# 0  1.68  4.75  ...      NaN       NaN      NaN                   0.0
# 1  1.40  4.64  ...      NaN       NaN      NaN                   0.0
# 2  1.09  4.55  ...      NaN       NaN      NaN                   0.0
# 3  2.44  4.55  ...      NaN       NaN      NaN                   1.0
# 4  2.82  4.52  ...      NaN       NaN      NaN                   1.0
#
#    pff_hitAllowed  pff_hurryAllowed pff_sackAllowed pff_nflIdBlockedPlayer  \
# ...

# %%
w2_T = w2_T.merge(games_df, how='left')
w2_T.head()
# Out:
#    nflId height  weight     displayName        gameId  playId  frameId team  \
# 0  42377    6-6     338   Donovan Smith  2.021092e+09  1840.0     15.0   TB
# 1  44876    6-5     325    Taylor Moton  2.021092e+09  3355.0     32.0  CAR
# 2  44876    6-5     325    Taylor Moton  2.021092e+09  3355.0     33.0  CAR
# 3  35443    6-5     320  Trent Williams  2.021092e+09  1215.0     34.0   SF
# 4  35443    6-5     320  Trent Williams  2.021092e+09  1215.0     33.0   SF
#
#       s     a  ...  pff_sackAllowed pff_nflIdBlockedPlayer pff_blockType  \
# 0  1.68  4.75  ...              0.0                42480.0            PP
# 1  1.40  4.64  ...              0.0                37097.0            PP
# 2  1.09  4.55  ...              0.0                37097.0            PP
# 3  2.44  4.55  ...              0.0                38542.0            PT
# 4  2.82  4.52  ...              0.0                38542.0            PT
#
# ...

# %%
w2_T.drop(columns=['homeTeamAbbr', 'visitorTeamAbbr','gameDate', 'gameTimeEastern', 'season'], inplace=True, errors='ignore')
w2_T.head()
# Out:
#    nflId height  weight     displayName        gameId  playId  frameId team  \
# 0  42377    6-6     338   Donovan Smith  2.021092e+09  1840.0     15.0   TB
# 1  44876    6-5     325    Taylor Moton  2.021092e+09  3355.0     32.0  CAR
# 2  44876    6-5     325    Taylor Moton  2.021092e+09  3355.0     33.0  CAR
# 3  35443    6-5     320  Trent Williams  2.021092e+09  1215.0     34.0   SF
# 4  35443    6-5     320  Trent Williams  2.021092e+09  1215.0     33.0   SF
#
#       s     a  ...  pff_hurry pff_sack pff_beatenByDefender  pff_hitAllowed  \
# 0  1.68  4.75  ...        NaN      NaN                  0.0             0.0
# 1  1.40  4.64  ...        NaN      NaN                  0.0             0.0
# 2  1.09  4.55  ...        NaN      NaN                  0.0             0.0
# 3  2.44  4.55  ...        NaN      NaN                  1.0             0.0
# 4  2.82  4.52  ...        NaN      NaN                  1.0             0.0
#
# ...

# %%
w2_T.to_csv('Resources/tackle_w2.csv', sep=',', index=False)

# %%
w2_T_df = pd.read_csv('Resources/tackle_w2.csv')
w2_T_df.head()
# Out:
#    nflId height  weight     displayName        gameId  playId  frameId team  \
# 0  42377    6-6     338   Donovan Smith  2.021092e+09  1840.0     15.0   TB
# 1  44876    6-5     325    Taylor Moton  2.021092e+09  3355.0     32.0  CAR
# 2  44876    6-5     325    Taylor Moton  2.021092e+09  3355.0     33.0  CAR
# 3  35443    6-5     320  Trent Williams  2.021092e+09  1215.0     34.0   SF
# 4  35443    6-5     320  Trent Williams  2.021092e+09  1215.0     33.0   SF
#
#       s     a  ...  pff_hurry pff_sack pff_beatenByDefender  pff_hitAllowed  \
# 0  1.68  4.75  ...        NaN      NaN                  0.0             0.0
# 1  1.40  4.64  ...        NaN      NaN                  0.0             0.0
# 2  1.09  4.55  ...        NaN      NaN                  0.0             0.0
# 3  2.44  4.55  ...        NaN      NaN                  1.0             0.0
# 4  2.82  4.52  ...        NaN      NaN                  1.0             0.0
#
# ...
