# %%
import csv
import os
import pandas as pd
import numpy as np

# %%
players_data_to_load = "Resources/players.csv"
week4_data_to_load = "Resources/week4.csv"
plays_data_to_load = "Resources/plays.csv"
pff_data_to_load = "Resources/pffScoutingData.csv"
games_data_to_load = "Resources/games.csv"

# %%
players_df = pd.read_csv(players_data_to_load)
players_df
# Out:
#       nflId height  weight   birthDate collegeName officialPosition  \
# 0     25511    6-4     225  1977-08-03    Michigan               QB
# 1     28963    6-5     240  1982-03-02   Miami, O.               QB
# 2     29550    6-4     328  1982-01-22    Arkansas                T
# 3     29851    6-2     225  1983-12-02  California               QB
# 4     30078    6-2     228  1982-11-24     Harvard               QB
# ...     ...    ...     ...         ...         ...              ...
# 1674  53991    6-1     320         NaN         NaN               DT
# 1675  53994    6-5     300         NaN         NaN                C
# 1676  53999    6-4     312         NaN         NaN               DT
# 1677  54006    6-6     330         NaN         NaN                T
# 1678  54038    6-6     245         NaN         NaN               QB
#
#              displayName
# 0              Tom Brady
# 1     Ben Roethlisberger
# 2           Jason Peters
# 3          Aaron Rodgers
# ...

# %%
week4_df = pd.read_csv(week4_data_to_load)
week4_df
# Out:
#              gameId  playId    nflId  frameId                     time  \
# 0        2021093000     169  38696.0        1  2021-10-01T00:29:42.800
# 1        2021093000     169  38696.0        2  2021-10-01T00:29:42.900
# 2        2021093000     169  38696.0        3  2021-10-01T00:29:43.000
# 3        2021093000     169  38696.0        4  2021-10-01T00:29:43.100
# 4        2021093000     169  38696.0        5  2021-10-01T00:29:43.200
# ...             ...     ...      ...      ...                      ...
# 1074601  2021100400    4161      NaN       46  2021-10-05T03:45:55.200
# 1074602  2021100400    4161      NaN       47  2021-10-05T03:45:55.300
# 1074603  2021100400    4161      NaN       48  2021-10-05T03:45:55.400
# 1074604  2021100400    4161      NaN       49  2021-10-05T03:45:55.500
# 1074605  2021100400    4161      NaN       50  2021-10-05T03:45:55.600
#
#          jerseyNumber      team playDirection      x      y      s     a  \
# ...

# %%
week4_players = players_df.merge(week4_df, how='left')
week4_players
# Out:
#          nflId height  weight   birthDate collegeName officialPosition  \
# 0        25511    6-4     225  1977-08-03    Michigan               QB
# 1        25511    6-4     225  1977-08-03    Michigan               QB
# 2        25511    6-4     225  1977-08-03    Michigan               QB
# 3        25511    6-4     225  1977-08-03    Michigan               QB
# 4        25511    6-4     225  1977-08-03    Michigan               QB
# ...        ...    ...     ...         ...         ...              ...
# 1028384  54006    6-6     330         NaN         NaN                T
# 1028385  54006    6-6     330         NaN         NaN                T
# 1028386  54006    6-6     330         NaN         NaN                T
# 1028387  54006    6-6     330         NaN         NaN                T
# 1028388  54038    6-6     245         NaN         NaN               QB
#
#             displayName        gameId  playId  frameId  ... team  \
# ...

# %% [markdown]
# ## Centers

# %%
week4_players_C = week4_players[week4_players['officialPosition'] == 'C']
week4_players_C.head()
# Out:
#        nflId height  weight   birthDate collegeName officialPosition  \
# 15556  34472    6-4     311  1985-11-19  California                C
# 15557  34472    6-4     311  1985-11-19  California                C
# 15558  34472    6-4     311  1985-11-19  California                C
# 15559  34472    6-4     311  1985-11-19  California                C
# 15560  34472    6-4     311  1985-11-19  California                C
#
#       displayName        gameId  playId  frameId  ... team  playDirection  \
# 15556   Alex Mack  2.021100e+09   149.0      1.0  ...   SF           left
# 15557   Alex Mack  2.021100e+09   149.0      2.0  ...   SF           left
# 15558   Alex Mack  2.021100e+09   149.0      3.0  ...   SF           left
# 15559   Alex Mack  2.021100e+09   149.0      4.0  ...   SF           left
# 15560   Alex Mack  2.021100e+09   149.0      5.0  ...   SF           left
#
#            x      y     s     a   dis       o     dir  event
# ...

# %%
week4_players_C = week4_players_C[week4_players_C['event'] != 'None']
week4_players_C
# Out:
#          nflId height  weight   birthDate collegeName officialPosition  \
# 15561    34472    6-4     311  1985-11-19  California                C
# 15562    34472    6-4     311  1985-11-19  California                C
# 15585    34472    6-4     311  1985-11-19  California                C
# 15587    34472    6-4     311  1985-11-19  California                C
# 15596    34472    6-4     311  1985-11-19  California                C
# ...        ...    ...     ...         ...         ...              ...
# 997345   53516    6-3     310         NaN         NaN                C
# 997346   53516    6-3     310         NaN         NaN                C
# 1006027  53543    6-3     300         NaN         NaN                C
# 1021181  53619    6-3     330         NaN         NaN                C
# 1028229  53994    6-5     300         NaN         NaN                C
#
#             displayName        gameId  playId  frameId  ... team  \
# ...

# %%
week4_players_C = week4_players_C.sort_values('a', ascending = False)
week4_players_C
# Out:
#          nflId height  weight   birthDate      collegeName officialPosition  \
# 267802   42476    6-4     309  1991-11-09          Florida                C
# 318381   43307    6-4     309  1993-05-30          Alabama                C
# 857447   52486    6-4     290  1997-11-17           Temple                C
# 923853   52894    6-4     315  1998-03-23         Missouri                C
# 267803   42476    6-4     309  1991-11-09          Florida                C
# ...        ...    ...     ...         ...              ...              ...
# 729350   47861    6-6     310  1996-09-03        Wisconsin                C
# 886905   52564    6-3     310  1998-07-25  San Diego State                C
# 1006027  53543    6-3     300         NaN              NaN                C
# 1021181  53619    6-3     330         NaN              NaN                C
# 1028229  53994    6-5     300         NaN              NaN                C
#
# ...

# %%
week4_players_C = week4_players_C.dropna()

# %%
cleaned_C= week4_players_C[['nflId', 'height', 'weight', 'displayName', 'gameId', 'playId', 'frameId', 'team', 's', 'a', 'dis', 'event']]
cleaned_C
# Out:
#         nflId height  weight       displayName        gameId  playId  frameId  \
# 267802  42476    6-4     309        Max Garcia  2.021100e+09   541.0     39.0
# 318381  43307    6-4     309        Ryan Kelly  2.021100e+09  1629.0     31.0
# 857447  52486    6-4     290     Matt Hennessy  2.021100e+09   208.0      6.0
# 923853  52894    6-4     315     Trystan Colon  2.021100e+09  3829.0     44.0
# 267803  42476    6-4     309        Max Garcia  2.021100e+09   541.0     40.0
# ...       ...    ...     ...               ...           ...     ...      ...
# 400851  43695    6-3     313        Matt Skura  2.021100e+09  3947.0      6.0
# 685721  47801    6-3     305  Garrett Bradbury  2.021100e+09  4103.0      6.0
# 400852  43695    6-3     313        Matt Skura  2.021100e+09  3947.0      7.0
# 268582  42476    6-4     309        Max Garcia  2.021100e+09  2342.0      1.0
# 684790  47801    6-3     305  Garrett Bradbury  2.021100e+09  1807.0      6.0
#
# ...

# %% [markdown]
# ## Guards

# %%
week4_players_G = week4_players[week4_players['officialPosition'] == 'G']
week4_players_G
# Out:
#          nflId height  weight   birthDate collegeName officialPosition  \
# 27379    35472    6-5     325  1988-06-06     Indiana                G
# 27380    35472    6-5     325  1988-06-06     Indiana                G
# 27381    35472    6-5     325  1988-06-06     Indiana                G
# 27382    35472    6-5     325  1988-06-06     Indiana                G
# 27383    35472    6-5     325  1988-06-06     Indiana                G
# ...        ...    ...     ...         ...         ...              ...
# 1025253  53655    6-6     325         NaN         NaN                G
# 1025254  53655    6-6     325         NaN         NaN                G
# 1025255  53655    6-6     325         NaN         NaN                G
# 1026284  53861    6-5     330         NaN         NaN                G
# 1026956  53954    6-5     319         NaN         NaN                G
#
#             displayName        gameId  playId  frameId  ... team  \
# ...

# %%
week4_players_G = week4_players_G[week4_players_G['event'] != 'None']
week4_players_G
# Out:
#          nflId height  weight   birthDate collegeName officialPosition  \
# 27384    35472    6-5     325  1988-06-06     Indiana                G
# 27394    35472    6-5     325  1988-06-06     Indiana                G
# 27436    35472    6-5     325  1988-06-06     Indiana                G
# 27447    35472    6-5     325  1988-06-06     Indiana                G
# 27449    35472    6-5     325  1988-06-06     Indiana                G
# ...        ...    ...     ...         ...         ...              ...
# 1025218  53655    6-6     325         NaN         NaN                G
# 1025226  53655    6-6     325         NaN         NaN                G
# 1025250  53655    6-6     325         NaN         NaN                G
# 1026284  53861    6-5     330         NaN         NaN                G
# 1026956  53954    6-5     319         NaN         NaN                G
#
#             displayName        gameId  playId  frameId  ... team  \
# ...

# %%
week4_players_G = week4_players_G.sort_values('a', ascending = False)

# %%
week4_players_G = week4_players_G.dropna()

# %%
cleaned_G = week4_players_G[['nflId', 'height', 'weight', 'displayName', 'gameId', 'playId', 'frameId', 'team', 's', 'a', 'dis', 'event']]
cleaned_G
# Out:
#         nflId height  weight            displayName        gameId  playId  \
# 302112  43045    6-4     330          Quinton Spain  2.021093e+09  1836.0
# 746749  47906    6-4     310             Ben Powers  2.021100e+09  1961.0
# 872133  52517    6-4     330           John Simpson  2.021100e+09   644.0
# 134078  40124    6-5     310     David Quessenberry  2.021100e+09  4824.0
# 132296  40124    6-5     310     David Quessenberry  2.021100e+09   203.0
# ...       ...    ...     ...                    ...           ...     ...
# 180372  41324    6-6     301      Michael Schofield  2.021100e+09  2659.0
# 375524  43453    6-6     320  Halapoulivaati Vaitai  2.021100e+09  3773.0
# 375573  43453    6-6     320  Halapoulivaati Vaitai  2.021100e+09  3795.0
# 375643  43453    6-6     320  Halapoulivaati Vaitai  2.021100e+09  3860.0
# 857302  52483    6-4     305          Jonah Jackson  2.021100e+09  3982.0
#
#         frameId team     s     a   dis                  event
# ...

# %% [markdown]
# ## Tackles

# %%
week4_players_T = week4_players[week4_players['officialPosition'] == 'T']
week4_players_T
# Out:
#          nflId height  weight   birthDate collegeName officialPosition  \
# 2960     29550    6-4     328  1982-01-22    Arkansas                T
# 2961     29550    6-4     328  1982-01-22    Arkansas                T
# 2962     29550    6-4     328  1982-01-22    Arkansas                T
# 2963     29550    6-4     328  1982-01-22    Arkansas                T
# 2964     29550    6-4     328  1982-01-22    Arkansas                T
# ...        ...    ...     ...         ...         ...              ...
# 1028383  54006    6-6     330         NaN         NaN                T
# 1028384  54006    6-6     330         NaN         NaN                T
# 1028385  54006    6-6     330         NaN         NaN                T
# 1028386  54006    6-6     330         NaN         NaN                T
# 1028387  54006    6-6     330         NaN         NaN                T
#
#           displayName        gameId  playId  frameId  ... team  playDirection  \
# ...

# %%
week4_players_T = week4_players_T[week4_players_T['event'] != 'None']
week4_players_T
# Out:
#          nflId height  weight   birthDate collegeName officialPosition  \
# 2965     29550    6-4     328  1982-01-22    Arkansas                T
# 2975     29550    6-4     328  1982-01-22    Arkansas                T
# 2988     29550    6-4     328  1982-01-22    Arkansas                T
# 2989     29550    6-4     328  1982-01-22    Arkansas                T
# 2993     29550    6-4     328  1982-01-22    Arkansas                T
# ...        ...    ...     ...         ...         ...              ...
# 1028346  54006    6-6     330         NaN         NaN                T
# 1028347  54006    6-6     330         NaN         NaN                T
# 1028357  54006    6-6     330         NaN         NaN                T
# 1028358  54006    6-6     330         NaN         NaN                T
# 1028382  54006    6-6     330         NaN         NaN                T
#
#           displayName        gameId  playId  frameId  ... team  playDirection  \
# ...

# %%
week4_players_T = week4_players_T.sort_values('a', ascending = False)

# %%
week4_players_T = week4_players_T.dropna()

# %%
cleaned_T = week4_players_T[['nflId', 'height', 'weight', 'displayName', 'gameId', 'playId', 'frameId', 'team', 's', 'a', 'dis', 'event']]
cleaned_T
# Out:
#         nflId height  weight       displayName        gameId  playId  frameId  \
# 6679    30869    6-7     330  Andrew Whitworth  2.021100e+09  3567.0     10.0
# 225417  42367    6-5     307    D.J. Humphries  2.021100e+09  2078.0     34.0
# 455881  44876    6-5     325      Taylor Moton  2.021100e+09  2299.0     35.0
# 559159  46092    6-2     310       Isaiah Wynn  2.021100e+09  3134.0      7.0
# 550386  46084    6-8     325     Kolton Miller  2.021100e+09  1384.0     32.0
# ...       ...    ...     ...               ...           ...     ...      ...
# 311985  43297    6-6     308      Jack Conklin  2.021100e+09  2393.0      6.0
# 775380  48181    6-7     314     Yosuah Nijman  2.021100e+09   401.0      6.0
# 311923  43297    6-6     308      Jack Conklin  2.021100e+09  2252.0      6.0
# 311760  43297    6-6     308      Jack Conklin  2.021100e+09  2052.0      6.0
# 225591  42367    6-5     307    D.J. Humphries  2.021100e+09  2342.0      1.0
#
# ...

# %% [markdown]
# ## Plays, PFF, & Games data added

# %%
plays_df = pd.read_csv(plays_data_to_load)
plays_df
# Out:
#           gameId  playId                                    playDescription  \
# 0     2021090900      97  (13:33) (Shotgun) T.Brady pass incomplete deep...
# 1     2021090900     137  (13:18) (Shotgun) D.Prescott pass deep left to...
# 2     2021090900     187  (12:23) (Shotgun) D.Prescott pass short middle...
# 3     2021090900     282  (9:56) D.Prescott pass incomplete deep left to...
# 4     2021090900     349  (9:46) (Shotgun) D.Prescott pass incomplete sh...
# ...          ...     ...                                                ...
# 8552  2021110100    4310  (1:56) (Shotgun) P.Mahomes sacked at NYG 16 fo...
# 8553  2021110100    4363  (1:07) (Shotgun) D.Jones pass short right to E...
# 8554  2021110100    4392  (1:01) (No Huddle, Shotgun) D.Jones sacked at ...
# 8555  2021110100    4411  (:39) (No Huddle, Shotgun) D.Jones pass incomp...
# 8556  2021110100    4433  (:35) (Shotgun) D.Jones sacked at NYG 14 for -...
#
# ...

# %%
pff_df = pd.read_csv(pff_data_to_load)
pff_df
# Out:
#             gameId  playId  nflId    pff_role pff_positionLinedUp  pff_hit  \
# 0       2021090900      97  25511        Pass                  QB      NaN
# 1       2021090900      97  35481  Pass Route                TE-L      NaN
# 2       2021090900      97  35634  Pass Route                 LWR      NaN
# 3       2021090900      97  39985  Pass Route                HB-R      NaN
# 4       2021090900      97  40151  Pass Block                   C      NaN
# ...            ...     ...    ...         ...                 ...      ...
# 188249  2021110100    4433  52507  Pass Block                  LT      NaN
# 188250  2021110100    4433  52546    Coverage               SCBoR      0.0
# 188251  2021110100    4433  52573  Pass Route               SLoWR      NaN
# 188252  2021110100    4433  52585   Pass Rush                 LEO      0.0
# 188253  2021110100    4433  53449  Pass Route                 LWR      NaN
#
#         pff_hurry  pff_sack  pff_beatenByDefender  pff_hitAllowed  \
# ...

# %%
games_df = pd.read_csv(games_data_to_load)
games_df
# Out:
#          gameId  season  week    gameDate gameTimeEastern homeTeamAbbr  \
# 0    2021090900    2021     1  09/09/2021        20:20:00           TB
# 1    2021091200    2021     1  09/12/2021        13:00:00          ATL
# 2    2021091201    2021     1  09/12/2021        13:00:00          BUF
# 3    2021091202    2021     1  09/12/2021        13:00:00          CAR
# 4    2021091203    2021     1  09/12/2021        13:00:00          CIN
# ..          ...     ...   ...         ...             ...          ...
# 117  2021103109    2021     8  10/31/2021        16:05:00          SEA
# 118  2021103110    2021     8  10/31/2021        16:25:00          DEN
# 119  2021103111    2021     8  10/31/2021        16:25:00           NO
# 120  2021103112    2021     8  10/31/2021        20:20:00          MIN
# 121  2021110100    2021     8  11/01/2021        20:15:00           KC
#
#     visitorTeamAbbr
# 0               DAL
# 1               PHI
# 2               PIT
# 3               NYJ
# ...

# %% [markdown]
# # Merging all data & Cleaning

# %% [markdown]
# ## Center

# %%
w4_C = cleaned_C.merge(plays_df, how="left")
w4_C.head()
# Out:
#    nflId height  weight    displayName        gameId  playId  frameId team  \
# 0  42476    6-4     309     Max Garcia  2.021100e+09   541.0     39.0  ARI
# 1  43307    6-4     309     Ryan Kelly  2.021100e+09  1629.0     31.0  IND
# 2  52486    6-4     290  Matt Hennessy  2.021100e+09   208.0      6.0  ATL
# 3  52894    6-4     315  Trystan Colon  2.021100e+09  3829.0     44.0  BAL
# 4  42476    6-4     309     Max Garcia  2.021100e+09   541.0     40.0  ARI
#
#       s     a  ...  foulNFLId3 absoluteYardlineNumber offenseFormation  \
# 0  1.03  4.05  ...         NaN                   40.0          SHOTGUN
# 1  2.00  3.91  ...         NaN                   34.0          SHOTGUN
# 2  0.80  3.85  ...         NaN                   49.0          SHOTGUN
# 3  3.92  3.84  ...         NaN                  108.0            JUMBO
# 4  1.17  3.80  ...         NaN                   40.0          SHOTGUN
#
#                personnelO  defendersInBox        personnelD dropBackType  \
# ...

# %%
w4_C.drop(columns=[['possessionTeam','pff_passCoverage','pff_passCoverageType']], inplace=True, errors='ignore')

# %%
w4_C = w4_C.merge(pff_df, how='left')
w4_C.head()
# Out:
#    nflId height  weight    displayName        gameId  playId  frameId team  \
# 0  42476    6-4     309     Max Garcia  2.021100e+09   541.0     39.0  ARI
# 1  43307    6-4     309     Ryan Kelly  2.021100e+09  1629.0     31.0  IND
# 2  52486    6-4     290  Matt Hennessy  2.021100e+09   208.0      6.0  ATL
# 3  52894    6-4     315  Trystan Colon  2.021100e+09  3829.0     44.0  BAL
# 4  42476    6-4     309     Max Garcia  2.021100e+09   541.0     40.0  ARI
#
#       s     a  ...  pff_hit pff_hurry pff_sack  pff_beatenByDefender  \
# 0  1.03  4.05  ...      NaN       NaN      NaN                   0.0
# 1  2.00  3.91  ...      NaN       NaN      NaN                   0.0
# 2  0.80  3.85  ...      NaN       NaN      NaN                   0.0
# 3  3.92  3.84  ...      NaN       NaN      NaN                   NaN
# 4  1.17  3.80  ...      NaN       NaN      NaN                   0.0
#
#    pff_hitAllowed  pff_hurryAllowed pff_sackAllowed pff_nflIdBlockedPlayer  \
# ...

# %%
w4_C = w4_C.merge(games_df, how='left')
w4_C.head()
# Out:
#    nflId height  weight    displayName        gameId  playId  frameId team  \
# 0  42476    6-4     309     Max Garcia  2.021100e+09   541.0     39.0  ARI
# 1  43307    6-4     309     Ryan Kelly  2.021100e+09  1629.0     31.0  IND
# 2  52486    6-4     290  Matt Hennessy  2.021100e+09   208.0      6.0  ATL
# 3  52894    6-4     315  Trystan Colon  2.021100e+09  3829.0     44.0  BAL
# 4  42476    6-4     309     Max Garcia  2.021100e+09   541.0     40.0  ARI
#
#       s     a  ...  pff_hit pff_hurry pff_sack  pff_beatenByDefender  \
# 0  1.03  4.05  ...      NaN       NaN      NaN                   0.0
# 1  2.00  3.91  ...      NaN       NaN      NaN                   0.0
# 2  0.80  3.85  ...      NaN       NaN      NaN                   0.0
# 3  3.92  3.84  ...      NaN       NaN      NaN                   NaN
# 4  1.17  3.80  ...      NaN       NaN      NaN                   0.0
#
#    pff_hitAllowed  pff_hurryAllowed pff_sackAllowed pff_nflIdBlockedPlayer  \
# ...

# %%
w4_C.drop(columns=['homeTeamAbbr', 'visitorTeamAbbr','gameDate', 'gameTimeEastern', 'season'], inplace=True, errors='ignore')
w4_C
# Out:
#       nflId height  weight       displayName        gameId  playId  frameId  \
# 0     42476    6-4     309        Max Garcia  2.021100e+09   541.0     39.0
# 1     43307    6-4     309        Ryan Kelly  2.021100e+09  1629.0     31.0
# 2     52486    6-4     290     Matt Hennessy  2.021100e+09   208.0      6.0
# 3     52894    6-4     315     Trystan Colon  2.021100e+09  3829.0     44.0
# 4     42476    6-4     309        Max Garcia  2.021100e+09   541.0     40.0
# ...     ...    ...     ...               ...           ...     ...      ...
# 3421  43695    6-3     313        Matt Skura  2.021100e+09  3947.0      6.0
# 3422  47801    6-3     305  Garrett Bradbury  2.021100e+09  4103.0      6.0
# 3423  43695    6-3     313        Matt Skura  2.021100e+09  3947.0      7.0
# 3424  42476    6-4     309        Max Garcia  2.021100e+09  2342.0      1.0
# 3425  47801    6-3     305  Garrett Bradbury  2.021100e+09  1807.0      6.0
#
# ...

# %%
w4_C.to_csv('Resources/center_w4.csv', sep=',', index=False)

# %%
w4_C_df = pd.read_csv('Resources/center_w4.csv')
w4_C_df.head()
# Out:
#    nflId height  weight    displayName        gameId  playId  frameId team  \
# 0  42476    6-4     309     Max Garcia  2.021100e+09   541.0     39.0  ARI
# 1  43307    6-4     309     Ryan Kelly  2.021100e+09  1629.0     31.0  IND
# 2  52486    6-4     290  Matt Hennessy  2.021100e+09   208.0      6.0  ATL
# 3  52894    6-4     315  Trystan Colon  2.021100e+09  3829.0     44.0  BAL
# 4  42476    6-4     309     Max Garcia  2.021100e+09   541.0     40.0  ARI
#
#       s     a  ...  pff_hit pff_hurry pff_sack  pff_beatenByDefender  \
# 0  1.03  4.05  ...      NaN       NaN      NaN                   0.0
# 1  2.00  3.91  ...      NaN       NaN      NaN                   0.0
# 2  0.80  3.85  ...      NaN       NaN      NaN                   0.0
# 3  3.92  3.84  ...      NaN       NaN      NaN                   NaN
# 4  1.17  3.80  ...      NaN       NaN      NaN                   0.0
#
#    pff_hitAllowed  pff_hurryAllowed pff_sackAllowed pff_nflIdBlockedPlayer  \
# ...

# %% [markdown]
# ## Guard

# %%
w4_G = cleaned_G.merge(plays_df, how="left")
w4_G.head()
# Out:
#    nflId height  weight         displayName        gameId  playId  frameId  \
# 0  43045    6-4     330       Quinton Spain  2.021093e+09  1836.0     12.0
# 1  47906    6-4     310          Ben Powers  2.021100e+09  1961.0     32.0
# 2  52517    6-4     330        John Simpson  2.021100e+09   644.0     20.0
# 3  40124    6-5     310  David Quessenberry  2.021100e+09  4824.0     41.0
# 4  40124    6-5     310  David Quessenberry  2.021100e+09   203.0     50.0
#
#   team     s     a  ...  foulNFLId3 absoluteYardlineNumber offenseFormation  \
# 0  CIN  2.63  5.32  ...         NaN                   32.0       SINGLEBACK
# 1  BAL  1.25  5.11  ...         NaN                   23.0            EMPTY
# 2   LV  3.48  4.57  ...         NaN                   87.0       SINGLEBACK
# 3  TEN  1.43  3.96  ...         NaN                   31.0          SHOTGUN
# 4  TEN  1.54  3.87  ...         NaN                   64.0           I_FORM
#
# ...

# %%
w4_G.drop(columns=[['possessionTeam','pff_passCoverage','pff_passCoverageType']], inplace=True, errors='ignore')
w4_G.head()
# Out:
#    nflId height  weight         displayName        gameId  playId  frameId  \
# 0  43045    6-4     330       Quinton Spain  2.021093e+09  1836.0     12.0
# 1  47906    6-4     310          Ben Powers  2.021100e+09  1961.0     32.0
# 2  52517    6-4     330        John Simpson  2.021100e+09   644.0     20.0
# 3  40124    6-5     310  David Quessenberry  2.021100e+09  4824.0     41.0
# 4  40124    6-5     310  David Quessenberry  2.021100e+09   203.0     50.0
#
#   team     s     a  ...  foulNFLId3 absoluteYardlineNumber offenseFormation  \
# 0  CIN  2.63  5.32  ...         NaN                   32.0       SINGLEBACK
# 1  BAL  1.25  5.11  ...         NaN                   23.0            EMPTY
# 2   LV  3.48  4.57  ...         NaN                   87.0       SINGLEBACK
# 3  TEN  1.43  3.96  ...         NaN                   31.0          SHOTGUN
# 4  TEN  1.54  3.87  ...         NaN                   64.0           I_FORM
#
# ...

# %%
w4_G = w4_G.merge(pff_df, how='left')
w4_G.head()
# Out:
#    nflId height  weight         displayName        gameId  playId  frameId  \
# 0  43045    6-4     330       Quinton Spain  2.021093e+09  1836.0     12.0
# 1  47906    6-4     310          Ben Powers  2.021100e+09  1961.0     32.0
# 2  52517    6-4     330        John Simpson  2.021100e+09   644.0     20.0
# 3  40124    6-5     310  David Quessenberry  2.021100e+09  4824.0     41.0
# 4  40124    6-5     310  David Quessenberry  2.021100e+09   203.0     50.0
#
#   team     s     a  ...  pff_hit pff_hurry pff_sack  pff_beatenByDefender  \
# 0  CIN  2.63  5.32  ...      NaN       NaN      NaN                   0.0
# 1  BAL  1.25  5.11  ...      NaN       NaN      NaN                   0.0
# 2   LV  3.48  4.57  ...      NaN       NaN      NaN                   0.0
# 3  TEN  1.43  3.96  ...      NaN       NaN      NaN                   0.0
# 4  TEN  1.54  3.87  ...      NaN       NaN      NaN                   0.0
#
# ...

# %%
w4_G = w4_G.merge(games_df, how='left')
w4_G.head()
# Out:
#    nflId height  weight         displayName        gameId  playId  frameId  \
# 0  43045    6-4     330       Quinton Spain  2.021093e+09  1836.0     12.0
# 1  47906    6-4     310          Ben Powers  2.021100e+09  1961.0     32.0
# 2  52517    6-4     330        John Simpson  2.021100e+09   644.0     20.0
# 3  40124    6-5     310  David Quessenberry  2.021100e+09  4824.0     41.0
# 4  40124    6-5     310  David Quessenberry  2.021100e+09   203.0     50.0
#
#   team     s     a  ...  pff_sackAllowed pff_nflIdBlockedPlayer pff_blockType  \
# 0  CIN  2.63  5.32  ...              0.0                42375.0            PA
# 1  BAL  1.25  5.11  ...              0.0                41464.0            PP
# 2   LV  3.48  4.57  ...              0.0                35485.0            PA
# 3  TEN  1.43  3.96  ...              1.0                53053.0            PP
# 4  TEN  1.54  3.87  ...              0.0                46204.0            PP
#
# ...

# %%
w4_G.drop(columns=['homeTeamAbbr', 'visitorTeamAbbr','gameDate', 'gameTimeEastern', 'season'], inplace=True, errors='ignore')
w4_G.head()
# Out:
#    nflId height  weight         displayName        gameId  playId  frameId  \
# 0  43045    6-4     330       Quinton Spain  2.021093e+09  1836.0     12.0
# 1  47906    6-4     310          Ben Powers  2.021100e+09  1961.0     32.0
# 2  52517    6-4     330        John Simpson  2.021100e+09   644.0     20.0
# 3  40124    6-5     310  David Quessenberry  2.021100e+09  4824.0     41.0
# 4  40124    6-5     310  David Quessenberry  2.021100e+09   203.0     50.0
#
#   team     s     a  ...  pff_hurry pff_sack pff_beatenByDefender  \
# 0  CIN  2.63  5.32  ...        NaN      NaN                  0.0
# 1  BAL  1.25  5.11  ...        NaN      NaN                  0.0
# 2   LV  3.48  4.57  ...        NaN      NaN                  0.0
# 3  TEN  1.43  3.96  ...        NaN      NaN                  0.0
# 4  TEN  1.54  3.87  ...        NaN      NaN                  0.0
#
#    pff_hitAllowed  pff_hurryAllowed  pff_sackAllowed pff_nflIdBlockedPlayer  \
# ...

# %%
w4_G.to_csv('Resources/guard_w4.csv', sep=',', index=False)

# %%
w4_G_df = pd.read_csv('Resources/guard_w4.csv')
w4_G_df.head()
# Out:
#    nflId height  weight         displayName        gameId  playId  frameId  \
# 0  43045    6-4     330       Quinton Spain  2.021093e+09  1836.0     12.0
# 1  47906    6-4     310          Ben Powers  2.021100e+09  1961.0     32.0
# 2  52517    6-4     330        John Simpson  2.021100e+09   644.0     20.0
# 3  40124    6-5     310  David Quessenberry  2.021100e+09  4824.0     41.0
# 4  40124    6-5     310  David Quessenberry  2.021100e+09   203.0     50.0
#
#   team     s     a  ...  pff_hurry pff_sack pff_beatenByDefender  \
# 0  CIN  2.63  5.32  ...        NaN      NaN                  0.0
# 1  BAL  1.25  5.11  ...        NaN      NaN                  0.0
# 2   LV  3.48  4.57  ...        NaN      NaN                  0.0
# 3  TEN  1.43  3.96  ...        NaN      NaN                  0.0
# 4  TEN  1.54  3.87  ...        NaN      NaN                  0.0
#
#    pff_hitAllowed  pff_hurryAllowed  pff_sackAllowed pff_nflIdBlockedPlayer  \
# ...

# %% [markdown]
# ## Tackle

# %%
w4_T = cleaned_T.merge(plays_df, how="left")
w4_T.head()
# Out:
#    nflId height  weight       displayName        gameId  playId  frameId team  \
# 0  30869    6-7     330  Andrew Whitworth  2.021100e+09  3567.0     10.0   LA
# 1  42367    6-5     307    D.J. Humphries  2.021100e+09  2078.0     34.0  ARI
# 2  44876    6-5     325      Taylor Moton  2.021100e+09  2299.0     35.0  CAR
# 3  46092    6-2     310       Isaiah Wynn  2.021100e+09  3134.0      7.0   NE
# 4  46084    6-8     325     Kolton Miller  2.021100e+09  1384.0     32.0   LV
#
#       s     a  ...  foulNFLId3 absoluteYardlineNumber offenseFormation  \
# 0  1.53  5.20  ...         NaN                   75.0            EMPTY
# 1  0.95  4.78  ...         NaN                   83.0          SHOTGUN
# 2  0.77  4.51  ...         NaN                   74.0          SHOTGUN
# 3  0.99  4.35  ...         NaN                   67.0            EMPTY
# 4  1.23  4.33  ...         NaN                   30.0          SHOTGUN
#
#          personnelO  defendersInBox        personnelD dropBackType  \
# ...

# %%
w4_T.drop(columns=['possessionTeam','pff_passCoverage','pff_passCoverageType'], inplace=True, errors='ignore')
w4_T.head()
# Out:
#    nflId height  weight       displayName        gameId  playId  frameId team  \
# 0  30869    6-7     330  Andrew Whitworth  2.021100e+09  3567.0     10.0   LA
# 1  42367    6-5     307    D.J. Humphries  2.021100e+09  2078.0     34.0  ARI
# 2  44876    6-5     325      Taylor Moton  2.021100e+09  2299.0     35.0  CAR
# 3  46092    6-2     310       Isaiah Wynn  2.021100e+09  3134.0      7.0   NE
# 4  46084    6-8     325     Kolton Miller  2.021100e+09  1384.0     32.0   LV
#
#       s     a  ...  foulNFLId2 foulName3 foulNFLId3  absoluteYardlineNumber  \
# 0  1.53  5.20  ...         NaN       NaN        NaN                    75.0
# 1  0.95  4.78  ...         NaN       NaN        NaN                    83.0
# 2  0.77  4.51  ...         NaN       NaN        NaN                    74.0
# 3  0.99  4.35  ...         NaN       NaN        NaN                    67.0
# 4  1.23  4.33  ...         NaN       NaN        NaN                    30.0
#
# ...

# %%
w4_T = w4_T.merge(pff_df, how='left')
w4_T.head()
# Out:
#    nflId height  weight       displayName        gameId  playId  frameId team  \
# 0  30869    6-7     330  Andrew Whitworth  2.021100e+09  3567.0     10.0   LA
# 1  42367    6-5     307    D.J. Humphries  2.021100e+09  2078.0     34.0  ARI
# 2  44876    6-5     325      Taylor Moton  2.021100e+09  2299.0     35.0  CAR
# 3  46092    6-2     310       Isaiah Wynn  2.021100e+09  3134.0      7.0   NE
# 4  46084    6-8     325     Kolton Miller  2.021100e+09  1384.0     32.0   LV
#
#       s     a  ...  pff_hit pff_hurry pff_sack  pff_beatenByDefender  \
# 0  1.53  5.20  ...      NaN       NaN      NaN                   0.0
# 1  0.95  4.78  ...      NaN       NaN      NaN                   0.0
# 2  0.77  4.51  ...      NaN       NaN      NaN                   0.0
# 3  0.99  4.35  ...      NaN       NaN      NaN                   0.0
# 4  1.23  4.33  ...      NaN       NaN      NaN                   0.0
#
#    pff_hitAllowed  pff_hurryAllowed pff_sackAllowed pff_nflIdBlockedPlayer  \
# ...

# %%
w4_T = w4_T.merge(games_df, how='left')
w4_T.head()
# Out:
#    nflId height  weight       displayName        gameId  playId  frameId team  \
# 0  30869    6-7     330  Andrew Whitworth  2.021100e+09  3567.0     10.0   LA
# 1  42367    6-5     307    D.J. Humphries  2.021100e+09  2078.0     34.0  ARI
# 2  44876    6-5     325      Taylor Moton  2.021100e+09  2299.0     35.0  CAR
# 3  46092    6-2     310       Isaiah Wynn  2.021100e+09  3134.0      7.0   NE
# 4  46084    6-8     325     Kolton Miller  2.021100e+09  1384.0     32.0   LV
#
#       s     a  ...  pff_sackAllowed pff_nflIdBlockedPlayer pff_blockType  \
# 0  1.53  5.20  ...              0.0                41403.0            PT
# 1  0.95  4.78  ...              0.0                46229.0            PP
# 2  0.77  4.51  ...              0.0                53513.0            PP
# 3  0.99  4.35  ...              0.0                47890.0            PP
# 4  1.23  4.33  ...              0.0                43377.0            PP
#
# ...

# %%
w4_T.drop(columns=['homeTeamAbbr', 'visitorTeamAbbr','gameDate', 'gameTimeEastern', 'season'], inplace=True, errors='ignore')
w4_T.head()
# Out:
#    nflId height  weight       displayName        gameId  playId  frameId team  \
# 0  30869    6-7     330  Andrew Whitworth  2.021100e+09  3567.0     10.0   LA
# 1  42367    6-5     307    D.J. Humphries  2.021100e+09  2078.0     34.0  ARI
# 2  44876    6-5     325      Taylor Moton  2.021100e+09  2299.0     35.0  CAR
# 3  46092    6-2     310       Isaiah Wynn  2.021100e+09  3134.0      7.0   NE
# 4  46084    6-8     325     Kolton Miller  2.021100e+09  1384.0     32.0   LV
#
#       s     a  ...  pff_hurry pff_sack pff_beatenByDefender  pff_hitAllowed  \
# 0  1.53  5.20  ...        NaN      NaN                  0.0             0.0
# 1  0.95  4.78  ...        NaN      NaN                  0.0             0.0
# 2  0.77  4.51  ...        NaN      NaN                  0.0             0.0
# 3  0.99  4.35  ...        NaN      NaN                  0.0             0.0
# 4  1.23  4.33  ...        NaN      NaN                  0.0             0.0
#
# ...

# %%
w4_T.to_csv('Resources/tackle_w4.csv', sep=',', index=False)

# %%
w4_T_df = pd.read_csv('Resources/tackle_w4.csv')
w4_T_df.head()
# Out:
#    nflId height  weight       displayName        gameId  playId  frameId team  \
# 0  30869    6-7     330  Andrew Whitworth  2.021100e+09  3567.0     10.0   LA
# 1  42367    6-5     307    D.J. Humphries  2.021100e+09  2078.0     34.0  ARI
# 2  44876    6-5     325      Taylor Moton  2.021100e+09  2299.0     35.0  CAR
# 3  46092    6-2     310       Isaiah Wynn  2.021100e+09  3134.0      7.0   NE
# 4  46084    6-8     325     Kolton Miller  2.021100e+09  1384.0     32.0   LV
#
#       s     a  ...  pff_hurry pff_sack pff_beatenByDefender  pff_hitAllowed  \
# 0  1.53  5.20  ...        NaN      NaN                  0.0             0.0
# 1  0.95  4.78  ...        NaN      NaN                  0.0             0.0
# 2  0.77  4.51  ...        NaN      NaN                  0.0             0.0
# 3  0.99  4.35  ...        NaN      NaN                  0.0             0.0
# 4  1.23  4.33  ...        NaN      NaN                  0.0             0.0
#
# ...
