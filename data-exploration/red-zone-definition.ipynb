# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
plays = pd.read_csv('../Resources/plays.csv')

# %%
# Red zone = line of scrimmage < 20yd line
plays['redZone'] = plays['absoluteYardlineNumber'] <= 30
red_zone_plays = plays.loc[plays['redZone']]
red_zone_plays.drop('redZone', axis=1, inplace=True)

# %%
red_zone_plays
# Out:
#           gameId  playId                                    playDescription  \
# 5     2021090900     410  (8:53) (Shotgun) T.Brady pass short middle to ...
# 19    2021090900    1078  (14:21) (No Huddle, Shotgun) D.Prescott pass s...
# 23    2021090900    1312  (9:53) T.Brady pass short right to R.Gronkowsk...
# 61    2021090900    3110  (7:12) (Shotgun) T.Brady pass short left to L....
# 62    2021090900    3134  (6:28) (Shotgun) T.Brady pass short middle to ...
# ...          ...     ...                                                ...
# 8541  2021110100    3617  (9:44) (Shotgun) P.Mahomes pass incomplete sho...
# 8542  2021110100    3674  (9:39) (Shotgun) P.Mahomes sacked at NYG 17 fo...
# 8552  2021110100    4310  (1:56) (Shotgun) P.Mahomes sacked at NYG 16 fo...
# 8555  2021110100    4411  (:39) (No Huddle, Shotgun) D.Jones pass incomp...
# 8556  2021110100    4433  (:35) (Shotgun) D.Jones sacked at NYG 14 for -...
#
#       quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 5           1     2          5             TB           DAL           TB
# 19          2     2          8            DAL            TB          DAL
# 23          2     2          2             TB           DAL          DAL
# 61          3     2          8             TB           DAL          DAL
# 62          3     3          6             TB           DAL          DAL
# ...       ...   ...        ...            ...           ...          ...
# 8541        4     2          9             KC           NYG          NYG
# 8542        4     3          9             KC           NYG          NYG
# 8552        4     3          8             KC           NYG          NYG
# 8555        4     3         15            NYG            KC          NYG
# 8556        4     4         15            NYG            KC          NYG
#
#       yardlineNumber  ... foulNFLId3  absoluteYardlineNumber  \
# 5                 11  ...        NaN                    21.0
# 19                 7  ...        NaN                    17.0
# 23                 2  ...        NaN                    12.0
# 61                13  ...        NaN                    23.0
# 62                11  ...        NaN                    21.0
# ...              ...  ...        ...                     ...
# 8541              12  ...        NaN                    22.0
# 8542              12  ...        NaN                    22.0
# 8552               8  ...        NaN                    18.0
# 8555              20  ...        NaN                    30.0
# 8556              20  ...        NaN                    30.0
#
#       offenseFormation        personnelO  defendersInBox        personnelD  \
# 5                EMPTY  1 RB, 1 TE, 3 WR             6.0  4 DL, 2 LB, 5 DB
# 19             SHOTGUN  1 RB, 0 TE, 4 WR             5.0  3 DL, 3 LB, 5 DB
# 23          SINGLEBACK  1 RB, 1 TE, 3 WR             7.0  4 DL, 2 LB, 5 DB
# 61             SHOTGUN  1 RB, 2 TE, 2 WR             7.0  4 DL, 2 LB, 5 DB
# 62               EMPTY  1 RB, 1 TE, 3 WR             6.0  4 DL, 2 LB, 5 DB
# ...                ...               ...             ...               ...
# 8541           SHOTGUN  1 RB, 1 TE, 3 WR             6.0  3 DL, 3 LB, 5 DB
# 8542           SHOTGUN  1 RB, 1 TE, 3 WR             4.0  1 DL, 3 LB, 7 DB
# 8552           SHOTGUN  1 RB, 1 TE, 3 WR             4.0  1 DL, 3 LB, 7 DB
# 8555           SHOTGUN  1 RB, 1 TE, 3 WR             5.0  4 DL, 1 LB, 6 DB
# 8556           SHOTGUN  1 RB, 1 TE, 3 WR             6.0  4 DL, 1 LB, 6 DB
#
#                 dropBackType pff_playAction  pff_passCoverage  \
# 5                TRADITIONAL              0           Cover-1
# 19               TRADITIONAL              0          Quarters
# 23    DESIGNED_ROLLOUT_RIGHT              1           Cover-1
# 61               TRADITIONAL              0          Quarters
# 62               TRADITIONAL              0           Cover-0
# ...                      ...            ...               ...
# 8541             TRADITIONAL              0          Red Zone
# 8542             TRADITIONAL              0           Bracket
# 8552                SCRAMBLE              0           Bracket
# 8555             TRADITIONAL              0           Cover-2
# 8556             TRADITIONAL              0          Quarters
#
#      pff_passCoverageType
# 5                     Man
# 19                   Zone
# 23                    Man
# 61                   Zone
# 62                    Man
# ...                   ...
# 8541                Other
# 8542                Other
# 8552                Other
# 8555                 Zone
# 8556                 Zone
#
# [1015 rows x 32 columns]
