# %%
# Import dependencies
import pandas as pd
import math
import psycopg2
from sqlalchemy import create_engine

# %%
# Store environment variable
from getpass import getpass
dbUser = getpass('Enter username')
dbPassword = getpass('Enter database password')
# Out:
# Enter username········
# Enter database password········

# %%
# Read data
plays = pd.read_csv('../Resources/plays.csv')
players = pd.read_csv('../Resources/players.csv')

week1 = pd.read_csv('../Resources/week1.csv')
week2 = pd.read_csv('../Resources/week2.csv')
week3 = pd.read_csv('../Resources/week3.csv')
week4 = pd.read_csv('../Resources/week4.csv')
week5 = pd.read_csv('../Resources/week5.csv')
week6 = pd.read_csv('../Resources/week6.csv')
week7 = pd.read_csv('../Resources/week7.csv')
week8 = pd.read_csv('../Resources/week8.csv')

# %%
# Concatenate week data
tracking = week1.append([
    week2,
    week3,
    week4,
    week5,
    week6,
    week7,
    week8,
])

# %%
# Slice for player tracking and merge officialPosition
player_tracking = tracking[tracking['team'] != 'football']
player_tracking = player_tracking.merge(players[['nflId', 'officialPosition']])

# %%
# Slice plays for Red Zone
plays['redZone'] = plays['absoluteYardlineNumber'] <= 30
red_zone_plays = plays.loc[plays['redZone']]
red_zone_plays.drop('redZone', axis=1, inplace=True)
# Out:
# C:\Users\lself\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# Slice tracking for Red Zone plays
player_tracking = player_tracking.merge(red_zone_plays[['gameId', 'playId']], how='right')

# %%
# Generate proximity table

# Initialize DataFrame to house proximity results
proximity_results = pd.DataFrame(columns=[
    'gameId',
    'playId',
    'frameId',
    'nflId',
    'nflId2',
    'distance'
])

# Perform merge on each game slice
for gameId in player_tracking['gameId'].unique():
    # Slice DataFrame for game
    game_tracking = player_tracking[player_tracking['gameId'] == gameId]
    
    # Merge offense and defense
    proximity = game_tracking.merge(
        game_tracking[['gameId', 'playId', 'frameId', 'nflId', 'x', 'y']],
        on=['gameId', 'playId', 'frameId'],
        how='left',
        suffixes=('', '2')
    )
    
    # Extract distance metric
    proximity['distance'] = proximity.apply(
        lambda row : math.sqrt(((row['x'] - row['x2'])**2 + (row['y'] - row['y2'])**2)), axis=1)
    
    # Clean distance proximity DataFrame to match results schema
    proximity = proximity[[
        'gameId',
        'playId',
        'frameId',
        'nflId',
        'nflId2',
        'distance'
    ]]
    
    # Append to DataFrame
    proximity_results = proximity_results.append(proximity)
    
    print(f"Game {gameId} has been processed. {len(proximity)} matchups were stored.")
# Out:
# Game 2021090900 has been processed. 108900 matchups were stored.
# Game 2021091200 has been processed. 194084 matchups were stored.
# Game 2021091201 has been processed. 107448 matchups were stored.
# Game 2021091202 has been processed. 99220 matchups were stored.
# Game 2021091203 has been processed. 113256 matchups were stored.
# Game 2021091204 has been processed. 158752 matchups were stored.
# Game 2021091205 has been processed. 151008 matchups were stored.
# Game 2021091206 has been processed. 239580 matchups were stored.
# Game 2021091207 has been processed. 216348 matchups were stored.
# Game 2021091208 has been processed. 251680 matchups were stored.
# Game 2021091209 has been processed. 147136 matchups were stored.
# Game 2021091210 has been processed. 98252 matchups were stored.
# Game 2021091211 has been processed. 182468 matchups were stored.
# Game 2021091212 has been processed. 261360 matchups were stored.
# Game 2021091213 has been processed. 150524 matchups were stored.
# Game 2021091300 has been processed. 204248 matchups were stored.
# Game 2021091600 has been processed. 100672 matchups were stored.
# Game 2021091900 has been processed. 122936 matchups were stored.
# Game 2021091901 has been processed. 119548 matchups were stored.
# Game 2021091902 has been processed. 66792 matchups were stored.
# Game 2021091903 has been processed. 115676 matchups were stored.
# Game 2021091904 has been processed. 67276 matchups were stored.
# Game 2021091905 has been processed. 268136 matchups were stored.
# Game 2021091906 has been processed. 149556 matchups were stored.
# Game 2021091907 has been processed. 124388 matchups were stored.
# Game 2021091908 has been processed. 93412 matchups were stored.
# Game 2021091909 has been processed. 15972 matchups were stored.
# Game 2021091910 has been processed. 226028 matchups were stored.
# Game 2021091911 has been processed. 174724 matchups were stored.
# Game 2021091912 has been processed. 168916 matchups were stored.
# Game 2021091913 has been processed. 128260 matchups were stored.
# Game 2021092000 has been processed. 166496 matchups were stored.
# Game 2021092300 has been processed. 123904 matchups were stored.
# Game 2021092600 has been processed. 292820 matchups were stored.
# Game 2021092601 has been processed. 75988 matchups were stored.
# Game 2021092602 has been processed. 353320 matchups were stored.
# Game 2021092603 has been processed. 120032 matchups were stored.
# Game 2021092604 has been processed. 292820 matchups were stored.
# Game 2021092605 has been processed. 134552 matchups were stored.
# Game 2021092606 has been processed. 105028 matchups were stored.
# Game 2021092607 has been processed. 270072 matchups were stored.
# Game 2021092608 has been processed. 67760 matchups were stored.
# Game 2021092609 has been processed. 104544 matchups were stored.
# Game 2021092610 has been processed. 254100 matchups were stored.
# Game 2021092611 has been processed. 192632 matchups were stored.
# Game 2021092612 has been processed. 125840 matchups were stored.
# Game 2021092613 has been processed. 270072 matchups were stored.
# Game 2021092700 has been processed. 175692 matchups were stored.
# Game 2021093000 has been processed. 134552 matchups were stored.
# Game 2021100300 has been processed. 152460 matchups were stored.
# Game 2021100301 has been processed. 230384 matchups were stored.
# Game 2021100302 has been processed. 158752 matchups were stored.
# Game 2021100303 has been processed. 244904 matchups were stored.
# Game 2021100304 has been processed. 203764 matchups were stored.
# Game 2021100305 has been processed. 292336 matchups were stored.
# Game 2021100306 has been processed. 199892 matchups were stored.
# Game 2021100307 has been processed. 223124 matchups were stored.
# Game 2021100308 has been processed. 135520 matchups were stored.
# Game 2021100309 has been processed. 307340 matchups were stored.
# Game 2021100310 has been processed. 123904 matchups were stored.
# Game 2021100311 has been processed. 235708 matchups were stored.
# Game 2021100312 has been processed. 84216 matchups were stored.
# Game 2021100313 has been processed. 268136 matchups were stored.
# Game 2021100400 has been processed. 377520 matchups were stored.
# Game 2021100700 has been processed. 174240 matchups were stored.
# Game 2021101000 has been processed. 92444 matchups were stored.
# Game 2021101001 has been processed. 167948 matchups were stored.
# Game 2021101002 has been processed. 135520 matchups were stored.
# Game 2021101003 has been processed. 112772 matchups were stored.
# Game 2021101004 has been processed. 239580 matchups were stored.
# Game 2021101005 has been processed. 34364 matchups were stored.
# Game 2021101006 has been processed. 42592 matchups were stored.
# Game 2021101007 has been processed. 148104 matchups were stored.
# Game 2021101008 has been processed. 226512 matchups were stored.
# Game 2021101009 has been processed. 207152 matchups were stored.
# Game 2021101010 has been processed. 246840 matchups were stored.
# Game 2021101011 has been processed. 49368 matchups were stored.
# Game 2021101012 has been processed. 73568 matchups were stored.
# Game 2021101013 has been processed. 196504 matchups were stored.
# Game 2021101100 has been processed. 153912 matchups were stored.
# Game 2021101400 has been processed. 73084 matchups were stored.
# Game 2021101700 has been processed. 160204 matchups were stored.
# Game 2021101701 has been processed. 119064 matchups were stored.
# Game 2021101702 has been processed. 246840 matchups were stored.
# Game 2021101703 has been processed. 132132 matchups were stored.
# Game 2021101704 has been processed. 185372 matchups were stored.
# Game 2021101705 has been processed. 58564 matchups were stored.
# Game 2021101706 has been processed. 261360 matchups were stored.
# Game 2021101707 has been processed. 185856 matchups were stored.
# Game 2021101708 has been processed. 100188 matchups were stored.
# Game 2021101709 has been processed. 167464 matchups were stored.
# Game 2021101710 has been processed. 242484 matchups were stored.
# Game 2021101711 has been processed. 58080 matchups were stored.
# Game 2021101800 has been processed. 85184 matchups were stored.
# Game 2021102100 has been processed. 242000 matchups were stored.
# Game 2021102400 has been processed. 39204 matchups were stored.
# Game 2021102401 has been processed. 335412 matchups were stored.
# Game 2021102402 has been processed. 155848 matchups were stored.
# Game 2021102403 has been processed. 33880 matchups were stored.
# Game 2021102404 has been processed. 223608 matchups were stored.
# Game 2021102405 has been processed. 213444 matchups were stored.
# Game 2021102406 has been processed. 307824 matchups were stored.
# Game 2021102407 has been processed. 138908 matchups were stored.
# Game 2021102408 has been processed. 118580 matchups were stored.
# Game 2021102409 has been processed. 150524 matchups were stored.
# Game 2021102410 has been processed. 163592 matchups were stored.
# Game 2021102500 has been processed. 139876 matchups were stored.
# Game 2021102800 has been processed. 141812 matchups were stored.
# Game 2021103100 has been processed. 88088 matchups were stored.
# Game 2021103101 has been processed. 137456 matchups were stored.
# Game 2021103102 has been processed. 116160 matchups were stored.
# Game 2021103103 has been processed. 288464 matchups were stored.
# Game 2021103104 has been processed. 116644 matchups were stored.
# Game 2021103105 has been processed. 245872 matchups were stored.
# Game 2021103106 has been processed. 201828 matchups were stored.
# Game 2021103107 has been processed. 242484 matchups were stored.
# Game 2021103108 has been processed. 188276 matchups were stored.
# Game 2021103109 has been processed. 325248 matchups were stored.
# Game 2021103110 has been processed. 186340 matchups were stored.
# Game 2021103111 has been processed. 241516 matchups were stored.
# Game 2021103112 has been processed. 163592 matchups were stored.
# Game 2021110100 has been processed. 237644 matchups were stored.

# %%
proximity_results = proximity_results[proximity_results['nflId'] != proximity_results['nflId2']]

# %%
# Write result to SQL table 
db = create_engine(f'postgresql://{dbUser}:{dbPassword}@34.72.136.99:5432/big-data-bowl')
conn = db.connect()
conn1 = psycopg2.connect(
    database="big-data-bowl",
    user=dbUser, 
    password=dbPassword, 
    host='34.72.136.99', 
    port= '5432'
)
  
conn1.autocommit = True
cursor = conn1.cursor()
  
# drop table if it already exists
cursor.execute('drop table if exists playerproximity')
    
sql_create = '''CREATE TABLE playerproximity(
    gameId integer,
    playId integer,
    frameId integer,
    nflId integer,
    nflId2 integer,
    distance double precision
);'''
  
cursor.execute(sql_create)

# converting data to sql
proximity_results.to_sql('playerproximity', conn, if_exists= 'replace', method='multi', index=False)
  
# fetching all rows
sql_select='''select * from playerproximity;'''
cursor.execute(sql_select)
for i in cursor.fetchall():
    print(i)
  
conn1.commit()
conn1.close()
